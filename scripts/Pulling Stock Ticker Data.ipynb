# %%
# This notebook shows how to use yfinance to pull stock ticker information

import pandas as pd
import yfinance as yf

# %%
data = yf.download('CORN','2021-01-01','2022-07-25')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
